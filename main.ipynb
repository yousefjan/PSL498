# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler
from sklearn.preprocessing import StandardScaler
import copy
import seaborn as sns
import tensorflow as tf
from sklearn.linear_model import LinearRegression
import Bio
# Out:
# /Users/yousefjan/PycharmProjects/peg_nn/venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
df_cols = ['dataset', 'model', 'WTS', 'spacer', 'extension', 'pbs_len', 'rtt_len', 'efficiency']
df = pd.read_csv("lib1.csv")
df.columns = df_cols
df.drop(['dataset', 'model', 'WTS', 'spacer', 'extension'], axis=1, inplace=True)
df.head()
# Out:
#    pbs_len  rtt_len  efficiency
# 0        7       10    0.035112
# 1        9       10    0.041597
# 2        7       10    0.000000
# 3        7       10    0.571349
# 4        7       12    0.000000

# %%
for label in df.columns[:-1]:
    plt.scatter(df[label], df["efficiency"])
    plt.title(label)
    plt.ylabel("Efficiency")
    plt.xlabel(label)
    plt.show()

# %%
train, val, test = np.split(df.sample(frac=1), [int(0.6*len(df)), int(0.8*len(df))])
# Out:
# /Users/yousefjan/PycharmProjects/peg_nn/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
